# %%
import pandas as pd

# %%
df=pd.read_csv('vih2.csv',  encoding='latin-1')

# %%
df
# Out:
#    Apellidos       Nombre  Edad  Lugar de residencia  Ocupación  Escolaridad  \
# 0     Espino       Moises  19.0                  0.0        2.0          4.0
# 1          G    Juan Jose  26.0                  0.0        0.0          5.0
# 2   Tovanche  Juan Daniel  28.0                  0.0        2.0          4.0
# 3   Martinez        Jesus  31.0                  0.0        2.0          5.0
# 4    Ramirez    Rigoberto  42.0                  0.0        2.0          3.0
# ..       ...          ...   ...                  ...        ...          ...
# 66  Carrillo      Enrique  32.0                  0.0        2.0          5.0
# 67      Leal        Johan  21.0                  0.0        0.0          5.0
# 68    Valdez        Laura  34.0                  0.0        0.0          4.0
# 69   Bolivar         Jose  42.0                  0.0        0.0          4.0
# 70   Cardiel          NaN   NaN                  NaN        NaN          NaN
#
# ...

# %%
display(df.dtypes)
# Out:
# Apellidos                                              object
# Nombre                                                 object
# Edad                                                  float64
# Lugar de residencia                                   float64
# Ocupación                                             float64
#                                                        ...
# Grado de conocimiento de métodos de protección        float64
# Conocimiento previo de métodos de quimioprofilaxis    float64
# Lugar de mayor aporte a la educación sexual           float64
# Conocimiento previo de pruebas contra ITS             float64
# Frecuencia de realización de pruebas contra ITS       float64
# Length: 71, dtype: object

# %%
df['Lugar de residencia'].dtype
# Out:
# dtype('float64')

# %%
df
# Out:
#    Apellidos       Nombre  Edad  Lugar de residencia  Ocupación  Escolaridad  \
# 0     Espino       Moises  19.0                  0.0        2.0          4.0
# 1          G    Juan Jose  26.0                  0.0        0.0          5.0
# 2   Tovanche  Juan Daniel  28.0                  0.0        2.0          4.0
# 3   Martinez        Jesus  31.0                  0.0        2.0          5.0
# 4    Ramirez    Rigoberto  42.0                  0.0        2.0          3.0
# ..       ...          ...   ...                  ...        ...          ...
# 66  Carrillo      Enrique  32.0                  0.0        2.0          5.0
# 67      Leal        Johan  21.0                  0.0        0.0          5.0
# 68    Valdez        Laura  34.0                  0.0        0.0          4.0
# 69   Bolivar         Jose  42.0                  0.0        0.0          4.0
# 70   Cardiel          NaN   NaN                  NaN        NaN          NaN
#
# ...

# %%
df['Lugar de residencia']= df['Lugar de residencia'].replace([0, 1, 2, 3, 4], ['Torreón', 'Gomez Palacio', 'Matamoros', 'Francisco I Madero', 'San Pedro'])

# %%
df
# Out:
#    Apellidos       Nombre  Edad Lugar de residencia  Ocupación  Escolaridad  \
# 0     Espino       Moises  19.0             Torreón        2.0          4.0
# 1          G    Juan Jose  26.0             Torreón        0.0          5.0
# 2   Tovanche  Juan Daniel  28.0             Torreón        2.0          4.0
# 3   Martinez        Jesus  31.0             Torreón        2.0          5.0
# 4    Ramirez    Rigoberto  42.0             Torreón        2.0          3.0
# ..       ...          ...   ...                 ...        ...          ...
# 66  Carrillo      Enrique  32.0             Torreón        2.0          5.0
# 67      Leal        Johan  21.0             Torreón        0.0          5.0
# 68    Valdez        Laura  34.0             Torreón        0.0          4.0
# 69   Bolivar         Jose  42.0             Torreón        0.0          4.0
# 70   Cardiel          NaN   NaN                 NaN        NaN          NaN
#
# ...

# %%
df['Escolaridad'].dtype
# Out:
# dtype('float64')

# %%
df['Escolaridad']= df['Escolaridad'].replace([0, 1, 2, 3, 4, 5, 6], ['Ninguna', 'Primaria incompleta', 'Primaria completa', 'Secundaria', 'Preparatoria', 'Profesional', 'Posgrado'])

# %%
df
# Out:
#    Apellidos       Nombre  Edad Lugar de residencia  Ocupación   Escolaridad  \
# 0     Espino       Moises  19.0             Torreón        2.0  Preparatoria
# 1          G    Juan Jose  26.0             Torreón        0.0   Profesional
# 2   Tovanche  Juan Daniel  28.0             Torreón        2.0  Preparatoria
# 3   Martinez        Jesus  31.0             Torreón        2.0   Profesional
# 4    Ramirez    Rigoberto  42.0             Torreón        2.0    Secundaria
# ..       ...          ...   ...                 ...        ...           ...
# 66  Carrillo      Enrique  32.0             Torreón        2.0   Profesional
# 67      Leal        Johan  21.0             Torreón        0.0   Profesional
# 68    Valdez        Laura  34.0             Torreón        0.0  Preparatoria
# 69   Bolivar         Jose  42.0             Torreón        0.0  Preparatoria
# 70   Cardiel          NaN   NaN                 NaN        NaN           NaN
#
# ...

# %%
df['Hospitalización previa']=df['Hospitalización previa'].astype(float)
df['¿Sífilis previa?']=df['¿Sífilis previa?'].astype(float)

# %%
df['¿Sífilis previa?']=df['¿Sífilis previa?'].astype(float)
df['¿Sífilis previa?']=df['¿Sífilis previa?'].astype(float)
df['¿Sífilis previa?']=df['¿Sífilis previa?'].astype(float)
df['¿Sífilis previa?']=df['¿Sífilis previa?'].astype(float)

# %%
df['Hospitalización previa']=df['Hospitalización previa'].replace([0, 1, 2], ['Sin hospitalización previa', 'Asociada a VIH', 'No asociada a VIH'])
df['¿Sífilis previa?']=df['¿Sífilis previa?'].replace([0, 1], ['SI', 'NO'])
df['¿Gonorrea previa?']=df['¿Gonorrea previa?'].replace([0, 1], ['SI', 'NO'])
df['¿VPH previo?']=df['¿VPH previo?'].replace([0, 1], ['SI', 'NO'])
df['¿CV previo?']=df['¿CV previo?'].replace([0, 1], ['SI', 'NO'])
df['¿VHC previa?']=df['¿VHC previa?'].replace([0, 1], ['SI', 'NO'])
df['¿Hérpes genital previo?']=df['¿Hérpes genital previo?'].replace([0, 1], ['SI', 'NO'])
df['¿Sífilis al diagnóstico?']=df['¿Sífilis al diagnóstico?'].replace([0, 1], ['SI', 'NO'])
df['¿Gonorrea al diagnóstico?']=df['¿Gonorrea al diagnóstico?'].replace([0,1], ['SI', 'NO'])
df['¿VPH al diagnóstico?']=df['¿VPH al diagnóstico?'].replace([0,1], ['SI', 'NO'])
df['¿CV al diagnóstico?']=df['¿CV al diagnóstico?'].replace([0,1], ['SI', 'NO'])
df['¿VHC al diagnóstico?']=df['¿VHC al diagnóstico?'].replace([0,1], ['SI', 'NO'])
df['¿Hérpes genital al diagnóstico?']=df['¿Hérpes genital al diagnóstico?'].replace([0,1],['SI', 'NO'])

# %%
fig=plt.figure(figsize=(12,10))
fig.suptitle('DATOS SOCIODEMOGRÁFICOS', fontweight='bold', fontsize=18)
ax1=fig.add_subplot(2,2,1)
ax1=sns.countplot(data=df, x='Sexo', palette='dark')
ax1.set(ylabel=None)
ax2=fig.add_subplot(2,2,2)
ax2=sns.countplot(data=df, x='Lugar de residencia',palette='dark')
ax2.set(ylabel=None)
ax3=fig.add_subplot(2,2,3)
ax3=sns.countplot(data=df, x='Escolaridad', palette='dark')
ax3.set(ylabel=None)
ax4=fig.add_subplot(2,2,4)
ax4=sns.countplot(data=df, x='Hospitalización previa', palette='dark')
ax4.set(ylabel=None)
fig.tight_layout()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df['Número de parejas sexuales'].fillna(0, inplace=True)
df['Relaciones sexuales con desconocidos'].fillna(0, inplace=True)
df['Relaciones sexuales con personas con VIH'].fillna(0, inplace=True)
df['Relaciones sexuales con usuarios de drogas IV'].fillna(0, inplace=True)
df['Lugar donde frecuentemente conoce a las parejas sexuales'].fillna(0, inplace=True)
df['Violencia sexual'].fillna(0, inplace=True)
df['Grado de conocimiento de métodos de protección'].fillna(0, inplace=True)
df['Conocimiento previo de VIH'].fillna(0, inplace=True)

# %%
df['Número de parejas sexuales']=df['Número de parejas sexuales'].astype(float)
df['Relaciones sexuales con desconocidos']=df['Relaciones sexuales con desconocidos'].astype(float)
df['Relaciones sexuales con personas con VIH']=df['Relaciones sexuales con personas con VIH'].astype(float)
df['Relaciones sexuales con usuarios de drogas IV']=df['Relaciones sexuales con usuarios de drogas IV'].astype(float)

# %%
df['Lugar donde frecuentemente conoce a las parejas sexuales']=df['Lugar donde frecuentemente conoce a las parejas sexuales'].astype(float)
df['Violencia sexual']=df['Violencia sexual'].astype(float)
df['Grado de conocimiento de métodos de  protección']=df['Grado de conocimiento de métodos de protección'].astype(float)
df['Conocimiento previo de VIH']=df['Conocimiento previo de VIH'].astype(float)

# %%
df['Lugar donde frecuentemente conoce a las parejas sexuales']=df['Lugar donde frecuentemente conoce a las parejas sexuales'].replace([0,1,2], ['Escuela o Trabajo', 'Redes sociales', 'Lugares de encuentro'])
df['Violencia sexual']=df['Violencia sexual'].replace([0,1],['NO', 'SI'])
df['Grado de conocimiento de métodos de protección']=df['Grado de conocimiento de métodos de protección'].replace([0,1,2,3,4], ['Nula', 'Escasa', 'Moderada', 'Buena', 'Excelente'])
df['Conocimiento previo de VIH']=df['Conocimiento previo de VIH'].replace([0,1], ['SI','NO'])

# %%
df['Marihuana']=df['Marihuana'].replace([0,1],['SI', 'NO'])
df['Alcohol']=df['Alcohol'].replace([0,1],['SI', 'NO'])
df['Cocaína']=df['Cocaína'].replace([0,1],['SI', 'NO'])
df['Drogas alucinógenas (LSD, hongos)']=df['Drogas alucinógenas (LSD, hongos)'].replace([0,1],['SI', 'NO'])

# %%
fig=plt.figure(figsize=(12,10))
ax1=fig.add_subplot(2,2,1)
ax1=sns.countplot(data=df, x='Marihuana', palette='dark')
ax1.set(ylabel=None)
ax2=fig.add_subplot(2,2,2)
ax2=sns.countplot(data=df, x='Alcohol',palette='dark')
ax2.set(ylabel=None)
ax3=fig.add_subplot(2,2,3)
ax3=sns.countplot(data=df, x='Cocaína', palette='dark')
ax3.set(ylabel=None)
ax4=fig.add_subplot(2,2,4)
ax4=sns.countplot(data=df, x='Drogas alucinógenas (LSD, hongos)', palette='dark')
ax4.set(ylabel=None)
fig.tight_layout()

# %%
df['Número de parejas sexuales']=df['Número de parejas sexuales'].replace([0,1,2], ['1 a 5 parejas', '6 a 10 parejas', 'Más de 10 parejas'])
df['Relaciones sexuales con desconocidos']=df['Relaciones sexuales con desconocidos'].replace([0,1], ['SI', 'NO'])
df['Relaciones sexuales con desconocidos']=df['Relaciones sexuales con desconocidos'].replace([0,1], ['SI', 'NO'])
df['Relaciones sexuales con personas con VIH']=df['Relaciones sexuales con personas con VIH'].replace([0,1], ['SI', 'NO'])
df['Relaciones sexuales con usuarios de drogas IV']=df['Relaciones sexuales con usuarios de drogas IV'].replace([0,1], ['SI', 'NO'])

# %%
df['Número de parejas sexuales'].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 66    False
# 67    False
# 68    False
# 69    False
# 70    False
# Name: Número de parejas sexuales, Length: 71, dtype: bool

# %%
fig=plt.figure(figsize=(12,10))
ax1=fig.add_subplot(2,2,1)
ax1=sns.countplot(data=df, x='Número de parejas sexuales', palette='dark')
ax1.set(ylabel=None)
ax2=fig.add_subplot(2,2,2)
ax2=sns.countplot(data=df, x='Relaciones sexuales con desconocidos',palette='dark')
ax2.set(ylabel=None)
ax3=fig.add_subplot(2,2,3)
ax3=sns.countplot(data=df, x='Relaciones sexuales con personas con VIH', palette='dark')
ax3.set(ylabel=None)
ax4=fig.add_subplot(2,2,4)
ax4=sns.countplot(data=df, x='Relaciones sexuales con usuarios de drogas IV', palette='dark')
ax4.set(ylabel=None)
fig.tight_layout()
